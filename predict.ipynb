# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/GenAI/ANN')

# %%
os.getcwd()
# Out:
# '/content/drive/MyDrive/GenAI/ANN'

# %%
os.listdir()
# Out:
# ['Churn_Modelling.csv',
#  'label_encoder_gender.pkl',
#  'onehot_encoder_geography.pkl',
#  'scaler.pkl',
#  'log',
#  'model.h5',
#  'classification_ANN.ipynb',
#  'predict.ipynb']

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
import pickle
import pandas as pd
import numpy as np

# %%
### load trained model, scaler pickle, onehotencoder
model = load_model('model.h5')

# load encoder and scaler
with open('label_encoder_gender.pkl', 'rb') as f:
    label_encoder_gender = pickle.load(f)

with open('scaler.pkl', 'rb') as f:
    scaler = pickle.load(f)

with open('onehot_encoder_geography.pkl', 'rb') as f:
    onehot_encoder_geography = pickle.load(f)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
input = {
    'CreditScore': 600,
    'Geography': 'France',
    'Gender': 'Male',
    'Age': 40,
    'Tenure': 3,
    'Balance': 60000,
    'NumOfProducts': 2,
    'HasCrCard': 1,
    'IsActiveMember': 1,
    'EstimatedSalary': 50000,

}

output = {
    'Exited': 0
}

# %%
input_df = pd.DataFrame([input])
input_df
# Out:
#    CreditScore Geography Gender  Age  Tenure  Balance  NumOfProducts  \
# 0          600    France   Male   40       3    60000              2
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1            50000

# %%
input_df['Gender'] = label_encoder_gender.transform(input_df['Gender'])

# %%
# Label and One Hot Encoder Use
geo_data = onehot_encoder_geography.transform(input_df[['Geography']])
geography_data = pd.DataFrame(geo_data, columns=onehot_encoder_geography.get_feature_names_out())
geography_data
# Out:
#    Geography_France  Geography_Germany  Geography_Spain
# 0               1.0                0.0              0.0

# %%
input_df = pd.concat([
    input_df.drop(["Geography"], axis = 1),
    geography_data], axis=1)

# %%
input_df
# Out:
#    CreditScore  Gender  Age  Tenure  Balance  NumOfProducts  HasCrCard  \
# 0          600       1   40       3    60000              2          1
#
#    IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# 0               1            50000               1.0                0.0
#
#    Geography_Spain
# 0              0.0

# %%
## Scaling the input
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-48ef49c5180b> in <cell line: 0>()
#       1 ## Scaling the input
# ----> 2 input_scale= scaler.trasform(input_df)
#
# AttributeError: 'StandardScaler' object has no attribute 'trasform'
